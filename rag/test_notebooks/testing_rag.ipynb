# %% [markdown]
# # This notebook is to be used to test new functionalities of the rag system

# %%
import os
import logging
from langchain_community.document_loaders import TextLoader
from langchain_community.document_loaders.pdf import PyPDFDirectoryLoader
from PyPDF2.errors import PdfStreamError
from langchain_text_splitters import RecursiveCharacterTextSplitter
from tqdm import tqdm

import os
import sys
from load_dotenv import load_dotenv

load_dotenv()
# %load_ext autoreload
# %autoreload 2
sys.path.append("../rag/")

# %%
document_path = "../../data"

def prepare_source(documents):
    for doc in tqdm(documents):
        source_data_split = doc.metadata["source"].split("\\")

        source_data_split = list(dict.fromkeys(source_data_split))
        k = [source_data_split.remove(l) for l in ["..", "data", "documents"] if l in source_data_split]
            
        source = '/'.join([str(elem) for elem in source_data_split])
        doc.metadata["source"] = source

def load_documents(DATA_PATH):
    documents = []
    
    def process_directory(dir_path):
        nonlocal documents
        
        items = os.listdir(dir_path)
        subdirs = [d for d in items if os.path.isdir(os.path.join(dir_path, d))]
        pdf_files = [f for f in items if f.lower().endswith('.pdf')]
        txt_files = [f for f in items if f.lower().endswith('.txt')]
        
        if not items or (not pdf_files and not txt_files and not subdirs):
            logging.info(f"No relevant files or subdirectories in {dir_path}, skipping...")
            return
        
        if pdf_files:
            logging.info(f"PDF files found in {dir_path}: {pdf_files}")
            document_loader = PyPDFDirectoryLoader(dir_path)
            try:
                # Try to load the documents and append to the documents list
                loaded_docs = document_loader.load()
                documents.extend(loaded_docs)
                logging.info(f"Successfully loaded {len(loaded_docs)} documents from PDFs in {dir_path}.")
            except PdfStreamError as e:
                logging.error(f"Error loading PDF in {dir_path}: {str(e)} - File might be corrupted.")
            except Exception as e:
                # Catch any other exceptions that may occur during PDF loading
                logging.error(f"Unexpected error loading PDFs in {dir_path}: {str(e)}")

        for subdir in subdirs:
            process_directory(os.path.join(dir_path, subdir))
    
    process_directory(DATA_PATH)
    logging.info(f"Total documents loaded: {len(documents)}")
    prepare_source(documents)
    logging.info(f"Formatted source correctly")

    return documents

# %%
document_loader = PyPDFDirectoryLoader(document_path).load()

# %%
document_loader
# Out:
# [Document(metadata={'source': '..\\..\\data\\Bodeguilla.pdf', 'page': 0}, page_content=''),
#  Document(metadata={'source': '..\\..\\data\\Bodeguilla.pdf', 'page': 1}, page_content=''),
#  Document(metadata={'source': '..\\..\\data\\Bodeguilla.pdf', 'page': 2}, page_content=''),
#  Document(metadata={'source': '..\\..\\data\\Bodeguilla.pdf', 'page': 3}, page_content='MALLORQUÍ\nTapes\n—Pernil ibèric de gla Juan Manuel D.O. Guijuelo (80g)\nCecina de bou, esparrecs, formatge Roncal i oli d’amontillat\nOstra Regal Special nº2 al natural (u.)\nOstra amb gaspatxo blanc de meló (u.)\nOstra a sa brasa amb gamba vermella a l’all\nCarpaccio de gamba vermella, fonoll marí i emulsió de ses caps\nTàrtar de tonyina, tomàtiga, alvocat a sa brasa i algues\nSteak tartar de vedella vella de muntanya\nEnsaladilla tradicional de patata amb gamba y mahonesa\nBurrata, albergínia rostida, tomàtigues escalivades i llimona  \nAmanida de tomàtigues de temporada, all verd de pinyons
#  Document(metadata={'source': '..\\..\\data\\Bodeguilla.pdf', 'page': 10}, page_content='*ALLE ANGEGEBENEN PREISE VERSTEHEN SICH INKLUSIVE MEHRWERTSTEUER  DEUTSCH\nReis \n&\nFisch\n—\nFleisch\n—\nBrötchenservice, Bio-Olivenöl extra vergine\nund gewürzte Oliven 3,50 € pro Person\nAioli 3,75 €\nBrot mit Tomaten und nativem Olivenöl extra 7,85 €\n‘Senyoret’ Reis mit Jakobsmuschel\nrote Garnelen und Tintenfisch\nHummereintopf mit Acuarello reis\nökologisch  (min. 2 Personen) (Preis pro Person)\nGegrillter W olfsbarsch mit Gemüse\nMallorquinisch und Algenbuttersauce\nJosper-Thunfischlende, geröstete Auberginen, \nKalamata-Oliven und ‘‘Piparras’’\nGebratener Hummer mit Knoblauch und Chili\nmit Pommes frites und Padrón-Paprika29.00€\n42.00€\n38.50€\n36.00€\n39.00€\nSpanferkel vom mallorquinischen schwarzen Schwein \nmit Bäckerinkartoffeln grüner Salat\nGeschmorte Lammschulter mit Honig und \nRosmarin und Bäckerinkartoffeln grüner Salat\n \nAusgewähltes Rinderfilet (250gr), grüne \nPfeffersauce  und Kartoffel-Millefeuille\nGegrillte Lammrippchen mit Knoblauch und Rosmarin\nmit Pommes frites und Padrón-Paprika\nGegrilltes Premium Rinderkotelett\n(mit “piquillo” Paprika und Pommes frites)\n(ideal zum Teilen) (Preis pro kg)36.00€\n39.00€\n38.00€\n36.00€\n85.00€'),
#  Document(metadata={'source': '..\\..\\data\\Bodeguilla.pdf', 'page': 11}, page_content='  LA-BODEGUILLA       LABODEGUILLA1986'),
#  Document(metadata={'source': '..\\..\\data\\Cucum.pdf', 'page': 0}, page_content=''),
#  Document(metadata={'source': '..\\..\\data\\Cucum.pdf', 'page': 1}, page_content=''),
#  Document(metadata={'source': '..\\..\\data\\Cucum.pdf', 'page': 2}, page_content=''),
#  Document(metadata={'source': '..\\..\\data\\Cucum.pdf', 'page': 3}, page_content=''),
#  Document(metadata={'source': '..\\..\\data\\Cucum.pdf', 'page': 4}, page_content=''),
#  Document(metadata={'source': '..\\..\\data\\Cucum.pdf', 'page': 5}, page_content=''),
#  Document(metadata={'source': '..\\..\\data\\Cucum.pdf', 'page': 6}, page_content=''),
#  Document(metadata={'source': '..\\..\\data\\Cucum.pdf', 'page': 7}, page_content=''),
#  Document(metadata={'source': '..\\..\\data\\Cucum.pdf', 'page': 8}, page_content=''),
#  Document(metadata={'source': '..\\..\\data\\Cucum.pdf', 'page': 9}, page_content=''),
#  Document(metadata={'source': '..\\..\\data\\Cucum.pdf', 'page': 10}, page_content=''),
#  Document(metadata={'source': '..\\..\\data\\Cucum.pdf', 'page': 11}, page_content=''),
#  Document(metadata={'source': '..\\..\\data\\Izizi Nunnak.pdf', 'page': 0}, page_content="Para compartir / To shareJamón ibérico de bellota cortado a cuchillo                                                                        27.00\nAcorn-fed iberian ham cut by hand\nAlmendras / Aceitunas  - Almonds / Olives             1.90\nServicio de pan / Bread service                3.90Nuestras bravas con mayo kimchee                                                                                           7.50\nBravas with kimchee mayo\nLangostino crujientes japo con mayo lima                                                                            
# %%
print(document_loader[3].page_content)
# Out:
# MALLORQUÍ
# Tapes
# —Pernil ibèric de gla Juan Manuel D.O. Guijuelo (80g)
# Cecina de bou, esparrecs, formatge Roncal i oli d’amontillat
# Ostra Regal Special nº2 al natural (u.)
# Ostra amb gaspatxo blanc de meló (u.)
# Ostra a sa brasa amb gamba vermella a l’all
# Carpaccio de gamba vermella, fonoll marí i emulsió de ses caps
# Tàrtar de tonyina, tomàtiga, alvocat a sa brasa i algues
# Steak tartar de vedella vella de muntanya
# Ensaladilla tradicional de patata amb gamba y mahonesa
# Burrata, albergínia rostida, tomàtigues escalivades i llimona
# Amanida de tomàtigues de temporada, all verd de pinyons i bacallà
# Espàrrecs verds a sa brasa amb romesco casolà i salsa tàrtara
# Les Braves de La Bodeguilla
# Ou a baixa temperatura amb salsa de foie i trufa fresca
# Croquetes meloses de pernil de Guijuelo (6u.)
# Zamburinyes amb picadillo i vinagre de Chardonnay (6u.)
# Calamars fregits amb allioli de prebes de Padró
# Fideuà de carrabiner i allioli dels seus corals
# Pop rostit amb ou, papada ibèrica i patata a s’all
# Caneló de pollastre camperol, salsa de trompetes i poma
# Ploma ibèrica a sa brasa, porro fumat, mostassa i festucs   26.00€
# 19.50€
# 4.85€
# 6.50€
# 7.50€
# 26.00€
# 24.50€
# 23.50€
# 18.00€
# 21.00€
# 19.00€
# 18.50€
# 16.50€
# 18.50€
# 18.00€
# 19.50€
# 22.50€
# 27.50€
# 28.00€
# 22.00€
# 29.00€

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("../../data/The Merchants.pdf")
pages = []
async for page in loader.alazy_load():
    pages.append(page)

# %%
pages
# Out:
# [Document(metadata={'source': '../../data/The Merchants.pdf', 'page': 0}, page_content="STARTERS & SHARING\nMAIN COURSE\nTo be enjoyed with a minimum of two courses per person beginning from when your food order is taken. \nIt is available for the alloted time of your reservation.\nWe are happy to provide information pertaining to allergens and intolerance on request. V - vegetarian, VG - vegan-8,&<\x03/8&<\x03%85*(5\n6WXIIHG\x03FKHGGDU\x03FKHHVH\x03SDWW\\\x0f\x03EDFRQ\x03\nWRPDWR\x03\t\x03SLFNOHV\n6·025(6\n$33/(\x03\t\x035$63%(55<\x03&580%/(\n6(/(&7,21\x032)\x03,&(\x03&5($06\x03\t\x03625%(76\n2 Courses €\x16\x1c / 3 courses €\x17\x18\nAdd frƺƺ\x03ˢowing of house wine or cava for €17.50 per personCHAMP MASH POT ATOES - €\x1a\x11\x13\x13\nGARDEN SALAD - €\x1a\x11\x13\x13\nFRIES WITH TRUFFLE AND PARMESAN - €\x1a\x11\x13\x13\nSAUCES - €3.\x18\x13 ( Peppecorn, Chimichurri, Bernaise \x03, Blue cheese)\nDESSERTS340g Ribeye
# 5(()	%(()681'$<52$67
# (Served with potatoes, vegetables, Yorkshire pudding & gravy)
# SIDES & SAUCES
# (Supplement charges apply on brunch menu)3($5	*2$7 &+((6(
# :DWHUFUHVVURFNHWJDUOLFEDOVDPLFKRQH\DOPRQGVRQLRQPDUPHODGH
# 52$67('3803.,1	&2&21876283
# &UXQFK\SXPSNLQVHHGV
# 60$6+('$92&$' 22172$67 	(**6
# 3RDFKHGHJJVVRXUGRXJK	UHGFKLOOLHV/2%67(5	35$:16&5248(7$6
# $YRFDGRSXUHH717VDXFH
# *5,//('/$0%&87/(76
# 6HVDPHRLOVULUDFKDVR\SLVWDFKLREORRGRUDQJHJHO
# SRPHJUDQDWH
# (**6%(1(',&7
# +RODQGDLVHVDXFHZLWKVSLQDFKRUKDPSUNDAY ROAST SET MENU
# 0LVRKRQH\OHPRQZDWHUFUHVVVSLQDFKVDOPRQURH*5,//('6$/0213$1)5,(''8&.%5($67
# %XWWHUQXWVTXDVKSXUHHSOXP	FUDQEHUU\VDXFH
# EDE\FDUURWV
# 9(*$1&$8/,)/2:(567($.
# 6HDVRQDOPXVKURRPJUDY\FKLD	SLVWDFFKLRVHHGV
# &251)('&+,&.(171735$:167LJHUSUDZQVLQWHPSXUDEDWWHUZLWK717VDXFH
# (Supplement of € )

# %% [markdown]
# # Using unstructured to read documents

# %%
import os
from load_dotenv import load_dotenv

load_dotenv()
unstructured_api = "https://api.unstructuredapp.io/general/v0/general"

# %%
import os, json

import unstructured_client
from unstructured_client.models import operations, shared

client = unstructured_client.UnstructuredClient(
    api_key_auth=os.getenv("UNSTRUCTURED_API_KEY"),
    server_url=os.getenv("UNSTRUCTURED_API_URL"),
)

filename = "../../data/Cucum.pdf"
with open(filename, "rb") as f:
    data = f.read()

req = operations.PartitionRequest(
    partition_parameters=shared.PartitionParameters(
        files=shared.Files(
            content=data,
            file_name=filename,
        ),
        strategy=shared.Strategy.HI_RES,
        languages=['eng'],
        split_pdf_page=True,            # If True, splits the PDF file into smaller chunks of pages.
        split_pdf_allow_failed=True,    # If True, the partitioning continues even if some pages fail.
        split_pdf_concurrency_level=15  # Set the number of concurrent request to the maximum value: 15.
    ),
)

# %%
res = client.general.partition(request=req)
element_dicts = [element for element in res.elements]

# Print the processed data's first element only.
print(element_dicts)
# Out:
# INFO: Preparing to split document for partition.
# INFO: Starting page number set to 1
# INFO: Allow failed set to 1
# INFO: Concurrency level set to 15
# INFO: Splitting pages 1 to 12 (12 total)
# INFO: Determined optimal split size of 2 pages.
# INFO: Partitioning 6 files with 2 page(s) each.
# INFO: Partitioning set #1 (pages 1-2).
# INFO: Partitioning set #2 (pages 3-4).
# INFO: Partitioning set #3 (pages 5-6).
# INFO: Partitioning set #4 (pages 7-8).
# INFO: Partitioning set #5 (pages 9-10).
# INFO: Partitioning set #6 (pages 11-12).
# INFO: HTTP Request: POST https://api.unstructuredapp.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructuredapp.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructuredapp.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructuredapp.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructuredapp.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructuredapp.io/general/v0/general "HTTP/1.1 200 OK"
# INFO

#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 8,
#    'filename': 'Cucum.pdf'}},
#  {'type': 'Image',
#   'element_id': '6a5929d205b3bea3de47466a4a644d85',
#   'text': "APERITIVOS - APERITIF 'VERMOUTH Yzaguirre HUGO DE FRESA Erdbeer Hugo / strawberry Hugo. APEROL SPRITZ .... 'MARTINI bianco / rosso / dry / rosato 'CAMPARI con zumo de naranja natural ‘mit frischem Orangensat - with fresh orange. 'CAMPARI SODA % 7 = /;‘j SANGRIA copa 0.3L - Glas - glass 490 jarra L - Krug - jag > \\A&m.,;\\ \\M Py— eAv copa 0.3L - Glas - glass. jarra L - Krug - jag. N . N (# LLET cucum STYLE Lillet Rosé, tonica de hibiscus, limay fresas Lillet Rosé, Hibiscus Tonic, Limette Lillet Rosé, hibiscus tonic, lime, strawberries DELIRIUM prosecco Wermut, Erdbeeren, Soda, vermouth, strawberries, sod, prosecco ARAVCTD 'vermouth, zumo de naranja, prosecco vermouth, orange juice, prosecco",
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 8,
#    'filename': 'Cucum.pdf'}},
#  {'type': 'UncategorizedText',
#   'element_id': 'e6fd2623393c332a1f49eefcbeed0679',
#   'text': '% & e',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 9,
#    'filename': 'Cucum.pdf'}},
#  {'type': 'ListItem',
#   'element_id': '0197c24c721d20775ea6e7a0651309ff',
#   'text': '<',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 9,
#    'filename': 'Cucum.pdf'}},
#  {'type': 'Title',
#   'element_id': '3dbb4d9729770ae3d014425de398174f',
#   'text': '/o',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 9,
#    'filename': 'Cucum.pdf'}},
#  {'type': 'Image',
#   'element_id': 'f201cf00e9ee7d1af925e9488de82f87',
#   'text': '704 ¢/',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 9,
#    'filename': 'Cucum.pdf'}},
#  {'type': 'NarrativeText',
#   'element_id': '651710ea4e240270065aba91a361e396',
#   'text': 'WEISSWEIN - WHITE WINE',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 9,
#    'filename': 'Cucum.pdf'}},
#  {'type': 'Table',
#   'element_id': 'e27be5eaa38d8076e697cb5e6b6db4be',
#   'text': 'VINO DE LA CASA - HAUSWEIN - HOME WINE opaisomi botella ARNE 450..... 21,00 DOC Rioja - ixpar\\a / Viura 450 21,00 D.O. Rueda - Espafia / Vierdejo, Viura 26,00 BLANC DE BLANCS J.L. FERRER num 1.5L. 5,50 55, D.O. Binissalem - Mallorca / Moll, Chardonnay, Moscate! Vi 590 28,00 DO, UtielRequena - Esparia / Chardonnay MACIA BATLE 590, 28,00 V.. de Mallorca / Moll, Chardonnay, Moscatel JOSE = 570 27,00 D.O. Rueda - Espaia /. A 32,00 D.O. Rias Baixas - Espafia / Albarifio BIC 570. 27,00 D.O. Rias Baixas - Espafia / Albarifio 5.70. 27,00 D.O. Rias Baixas - Espafia / Albarifio 590 28,00 D.O. Monterrei - Espal',
#   'metadata': {'text_as_html': '<table><thead><tr><th>VINO DE LA CASA - HAUSWEIN - HOME WINE ARNEGUI DOC Rioja - Espa</th><th>copa tsomi botelia 450 21,00</th></tr></thead><tbody><tr><td>D.O. Rueda</td><td>450 1,00</td></tr><tr><td>BLANC DE BLANCS J.L. FERRER</td><td>6,00</td></tr><tr><td colspan="2">55, D.O. Binissalem - Mallorca / Moll, Chardonnay, Mo

#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 12,
#    'filename': 'Cucum.pdf'}}]

# %%
json_elements = json.dumps(element_dicts, indent=2)

with open("../../data/output/Cucum_data.json", "w") as file:
    file.write(json_elements)

# %%
import pandas as pd
pd.DataFrame(element_dicts)
# Out:
#                  type                        element_id  \
# 0               Title  3089f82c45e8e26409ed9cabd911ab84
# 1               Title  0511964e7e5d58b160d7845764d029a5
# 2       NarrativeText  8b3750007f8f1b00be82b97c235c04c6
# 3       NarrativeText  265a88458ec173a70ddb2a584cd575d4
# 4       NarrativeText  dae0ffb9e88d00c4d6db21ca19253d68
# 5       NarrativeText  bc13362081559cce2df5f73dd5c48c7d
# 6               Title  27dfa2b71567c1abeaaf6176b8f74d16
# 7       NarrativeText  90bd57aa41b9d6860cc8af7cad3d94fe
# 8               Title  3bd236451dd7c03c87588a30bd01d115
# 9       NarrativeText  0d38724c47c3a9df423f2973d36a37c8
# 10              Title  1014464cc070fb592e989e2a170d2416
# 11      NarrativeText  0c983df83ef495ca5b7d1bced37f3e9a
# 12              Title  d986fa8142d70d0307c9b5a30c117ed7
# 13      NarrativeText  1a2b396018bffe93e0a5a2ecf66f05e5
# 14              Title  7032801172055969b2aa353f01bc567a
# 15      NarrativeText  1931c02ea5e8ba7352f36bd8f4713e0c
# 16      NarrativeText  7ef61c04911a63334b9c5359c4ac4006
# 17              Title  465bcb9ab38111f5f14433ac8a965e7a
# 18      NarrativeText  ce395ca8886111f6160f1f77ee61c59d
# 19      NarrativeText  617e1e19c43734832106f82707c63344
# 20              Title  010b4644f7f794aa239232d7a7d8e144
# 21      NarrativeText  bbc4d509208e7dcda917ec3e13f2a662
# 22      NarrativeText  160049e5e2a960ac89d09abddf88c26c
# 23      NarrativeText  c42db7705d5195035acde14e2e124d98
# 24      NarrativeText  a0da070d978823d5f1810f8d9365a408
# 25      NarrativeText  ad0d26580e3c6fd44df4ed0b5c34a4e6
# 26              Title  a2ba038ebe73e9ea59310f37ec732faf
# 27      NarrativeText  f3221120b972db44103e634b8ccf4039
# 28      NarrativeText  b9900e7c9901b14a5bcf05376acb8409
# 29              Title  44db70e77ab70686b65de1b28a51a736
# 30              Title  b0840a92847e53fc4a65eb7fbdd732e0
# 31      NarrativeText  3673f552855f90ebfdcc7721de765b1e
# 32              Title  92560a448e27d1978396a5a1f81a329b
# 33      NarrativeText  e0b318f765b3842cba94375728466c41
# 34      NarrativeText  cea9ff5586352c1d0d210ecf0eeb6b30
# 35              Title  1e7873d4123aaf14de43967210d19c0e
# 36           ListItem  2948c665e897b2eacb34e12ae14ae3e3
# 37  UncategorizedText  378cc34acdcbbe4e1e562be77a524da2
# 38      NarrativeText  8f9570f8aedc400b4e80aca855521556
# 39      NarrativeText  0156aef5749facc0a426ba078c14ce30
# 40              Title  73bf912cfbe4cfd36d6cb2101d1869ad
# 41      NarrativeText  cfb141b75f972b5778260d8bb751e698
# 42              Title  4e80a459c4b8aeea81633595c171071f
# 43      NarrativeText  391e63071d178f426f272df62781e23e
# 44      NarrativeText  5f2aad0155031fdc1709fa4f3d6adf3e
# 45      NarrativeText  e847c46eab4e09531b517314939db9b2
# 46      NarrativeText  220bbb64ee83ccff36dabea6de597fdb
#
#                                                  text  \
# 0                               SUNDAY ROAST SET MENU
# 1                                  STARTERS & SHARING
# 2                          LOBSTER & PRAWNS CROQUETAS
# 3                            Avocado puree, TNT sauce
# 4                                GRILLED LAMB CUTLETS
# 5   Sesame oil, sriracha, soy, pistachio, blood or...
# 6                                       EGGS BENEDICT
# 7                Holandaise sauce with spinach or ham
# 8                                  PEAR & GOAT CHEESE
# 9   Watercress, rocket, garlic, balsamic, honey, a...
# 10                     ROASTED PUMPKIN & COCONUT SOUP
# 11                              Crunchy pumpkin seeds
# 12                    SMASHED AVOCADO ON TOAST & EGGS
# 13             Poached eggs, sourdough & red chillies
# 14                                          in batter
# 15      Tiger prawns in tempura batter with TNT sauce
# 16                                 (Supplement of €8)
# 17                                        MAIN COURSE
# 18                                  JUICY LUCY BURGER
# 19  Stuffed cheddar cheese patty, bacon tomato & p...
# 20                                     GRILLED SALMON
# 21  Miso, honey, lemon, watercress, spinach, salmo...
# 22                              PAN FRIED DUCK BREAST
# 23  Butternut squash puree, plum & cranberry sauce...
# 24                            VEGAN CAULIFLOWER STEAK
# 25   Seasonal mushroom gravy, chia & pistacchio seeds
# 26                                       SUNDAY ROAST
# 27  (Served with potatoes, vegetables, Yorkshire p...
# 28                                         PORK BELLY
# 29              BELLY ROASTED SIRLOIN CORNFED CHICKEN
# 30                                        REEF & BEEF
# 31  3409 Ribeye steak, half Canadian lobster, frie...
# 32                                     SIDES & SAUCES
# 33          (Supplement charges apply on brunch menu)
# 34                        CHAMP MASH POTATOES - €7.00
# 35                                       GARDEN SALAD
# 36
# 37                                              €7.00
# 38            FRIES WITH TRUFFLE AND PARMESAN - €7.00
# 39  SAUCES - €3.50 (Peppecorn, Chimichurri, Bernai...
# 40                                           DESSERTS
# 41                                            S’MORES
# 42                          APPLE & RASPBERRY CRUMBLE
# 43                  SELECTION OF ICE CREAMS & SORBETS
# 44  To be enjoyed with a minimum of two courses pe...
# 45  It is available for the alloted time of your r...
# 46  We are happy to provide information pertaining...
#
#                                              metadata
# 0   {'filetype': 'application/pdf', 'languages': [...
# 1   {'filetype': 'application/pdf', 'languages': [...
# 2   {'filetype': 'application/pdf', 'languages': [...
# 3   {'filetype': 'application/pdf', 'languages': [...
# 4   {'filetype': 'application/pdf', 'languages': [...
# 5   {'filetype': 'application/pdf', 'languages': [...
# 6   {'filetype': 'application/pdf', 'languages': [...
# 7   {'filetype': 'application/pdf', 'languages': [...
# 8   {'filetype': 'application/pdf', 'languages': [...
# 9   {'filetype': 'application/pdf', 'languages': [...
# 10  {'filetype': 'application/pdf', 'languages': [...
# 11  {'filetype': 'application/pdf', 'languages': [...
# 12  {'filetype': 'application/pdf', 'languages': [...
# 13  {'filetype': 'application/pdf', 'languages': [...
# 14  {'filetype': 'application/pdf', 'languages': [...
# 15  {'filetype': 'application/pdf', 'languages': [...
# 16  {'filetype': 'application/pdf', 'languages': [...
# 17  {'filetype': 'application/pdf', 'languages': [...
# 18  {'filetype': 'application/pdf', 'languages': [...
# 19  {'filetype': 'application/pdf', 'languages': [...
# 20  {'filetype': 'application/pdf', 'languages': [...
# 21  {'filetype': 'application/pdf', 'languages': [...
# 22  {'filetype': 'application/pdf', 'languages': [...
# 23  {'filetype': 'application/pdf', 'languages': [...
# 24  {'filetype': 'application/pdf', 'languages': [...
# 25  {'filetype': 'application/pdf', 'languages': [...
# 26  {'filetype': 'application/pdf', 'languages': [...
# 27  {'filetype': 'application/pdf', 'languages': [...
# 28  {'filetype': 'application/pdf', 'languages': [...
# 29  {'filetype': 'application/pdf', 'languages': [...
# 30  {'filetype': 'application/pdf', 'languages': [...
# 31  {'filetype': 'application/pdf', 'languages': [...
# 32  {'filetype': 'application/pdf', 'languages': [...
# 33  {'filetype': 'application/pdf', 'languages': [...
# 34  {'filetype': 'application/pdf', 'languages': [...
# 35  {'filetype': 'application/pdf', 'languages': [...
# 36  {'filetype': 'application/pdf', 'languages': [...
# 37  {'filetype': 'application/pdf', 'languages': [...
# 38  {'filetype': 'application/pdf', 'languages': [...
# 39  {'filetype': 'application/pdf', 'languages': [...
# 40  {'filetype': 'application/pdf', 'languages': [...
# 41  {'filetype': 'application/pdf', 'languages': [...
# 42  {'filetype': 'application/pdf', 'languages': [...
# 43  {'filetype': 'application/pdf', 'languages': [...
# 44  {'filetype': 'application/pdf', 'languages': [...
# 45  {'filetype': 'application/pdf', 'languages': [...
# 46  {'filetype': 'application/pdf', 'languages': [...

# %%
print(element_dicts[1]["text"])
# Out:
# ZUMOS MATURALES HATHRLICHE SAFTE ... MATURAL IUICES HASTA 18:00H / BIS 18:00 UHR / TILL 6 P.M. DE 390 frisch gepresster Orangensaft / fresh orange juice TROPICAL mango, fresa y nara 590 Mango, Erdbeere, Orange / mango, strawberry, orange EL SOL zanahoria, jengibre, naranja y miel Karotte, Ingwer, Orange, Honig / carrot, ginger, orange, honey *‘l‘g‘ R !‘l\ A\ EMPEZANDO BIEN EL DIA .. DESAYUNDS .. FRUHSTUCK .. BREAKFAST HASTA 12:00H / BIS 12:00 UHR / TILL 12 NOON DESAYUNO CUCUM 1690 fresCo con ceboliing, variado de. cbrsseizo e e Aucheilel Lachs, Frlschklse ‘mit Schnittiauch, tulielsaloml. Kr&uretsalamt Iogmm mlr Frichten, verschiedene Backwaren, frisch Oranqensa n, gerducherter Kochschinken, K: herb salami cookedham smoked cool ream cheese with d\lves. cheese vanefy l!ulﬂe salami, e S e LR T 990 D%“v’am croissant, frisches Obst, Croissant, Marmelade, Nutella, Butter fresh fruits, croissant, jam, nutella, butter TOSTADA CON 9.90 = Jamon York y queso Mahan roas( mit Tomalen Olivendl, gekochtem Schinken und Mahon-Kése Toast with tomato, olive oil, cooked ham and Mahén cheese (&) TOSTADA oumm;o Toasr mit Tomaten, Olivend, iberischem Schinken Toast with tomato, olive oil, Iberian ham - & TOSTADA ON 1290 * con crema ), salmén Toast mit Friscl Toast with cream cheese, smoked sal se, Raucherlachs, Avocado und Rucola , avocado and arugula SO = mitJoghurt, MGl und schern C i 890 with yogurt, cereals and fresh fruits (@) e HUEVOS REVUELTOS 690 Rahrei Scrambled eggs con jamén york mit Kochschinken / oder Speck 790 with cooked ham / or bacon ccon jamén ibérico. 890 mit iberischem Schinken with iberian ham (o) FRITOS con bacon 790 jer mit Speck «eggs with bacon

# %%
element_dicts[1]["text"]

# %%
from unstructured.partition.pdf import partition_pdf

elements = partition_pdf("../../data/Cucum.pdf")

elements_fast = partition_pdf("../../data/Cucum.pdf", strategy="fast")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\ZENBOOK\anaconda3\envs\soma\lib\site-packages\pdf2image\pdf2image.py:581, in pdfinfo_from_path(pdf_path, userpw, ownerpw, poppler_path, rawdates, timeout, first_page, last_page)
#     580     env["LD_LIBRARY_PATH"] = poppler_path + ":" + env.get("LD_LIBRARY_PATH", "")
# --> 581 proc = Popen(command, env=env, stdout=PIPE, stderr=PIPE)
#     583 try:
#
# File c:\Users\ZENBOOK\anaconda3\envs\soma\lib\subprocess.py:966, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     963             self.stderr = io.TextIOWrapper(self.stderr,
#     964                     encoding=encoding, errors=errors)
# --> 966     self._execute_child(args, executable, preexec_fn, close_fds,
#     967                         pass_fds, cwd, env,
#     968                         startupinfo, creationflags, shell,
#     969                         p2cread, p2cwrite,
#     970                         c2pread, c2pwrite,
#     971                         errread, errwrite,
#     972                         restore_signals,
#     973                         gid, gids, uid, umask,
#     974                         start_new_session)
#     975 except:
#     976     # Cleanup if the child failed starting.
#
# File c:\Users\ZENBOOK\anaconda3\envs\soma\lib\subprocess.py:1435, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1434 try:
# -> 1435     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1436                              # no special security
#    1437                              None, None,
#    1438                              int(not close_fds),
#    1439                              creationflags,
#    1440                              env,
#    1441                              cwd,
#    1442                              startupinfo)
#    1443 finally:
#    1444     # Child is launched. Close the parent's copy of those pipe
#    1445     # handles that only the child should have open.  You need
#    (...)
#    1448     # pipe will not close when the child process exits and the
#    1449     # ReadFile will hang.
#
# FileNotFoundError: [WinError 2] Le fichier spécifié est introuvable
#
# During handling of the above exception, another exception occurred:
#
# PDFInfoNotInstalledError                  Traceback (most recent call last)
# Cell In[74], line 3
#       1 from unstructured.partition.pdf import partition_pdf
# ----> 3 elements = partition_pdf("../../data/Cucum.pdf")
#       5 elements_fast = partition_pdf("../../data/Cucum.pdf", strategy="fast")
#
# File c:\Users\ZENBOOK\anaconda3\envs\soma\lib\site-packages\unstructured\documents\elements.py:605, in process_metadata.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     603 @functools.wraps(func)
#     604 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> list[Element]:
# --> 605     elements = func(*args, **kwargs)
#     606     call_args = get_call_args_applying_defaults(func, *args, **kwargs)
#     608     regex_metadata: dict["str", "str"] = call_args.get("regex_metadata", {})
#
# File c:\Users\ZENBOOK\anaconda3\envs\soma\lib\site-packages\unstructured\file_utils\filetype.py:731, in add_filetype.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     729 @functools.wraps(func)
#     730 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> list[Element]:
# --> 731     elements = func(*args, **kwargs)
#     732     params = get_call_args_applying_defaults(func, *args, **kwargs)
#     733     include_metadata = params.get("include_metadata", True)
#
# File c:\Users\ZENBOOK\anaconda3\envs\soma\lib\site-packages\unstructured\file_utils\filetype.py:687, in add_metadata.<locals>.wrapper(*args, **kwargs)
#     685 @functools.wraps(func)
#     686 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> list[Element]:
# --> 687     elements = func(*args, **kwargs)
#     688     call_args = get_call_args_applying_defaults(func, *args, **kwargs)
#     689     include_metadata = call_args.get("include_metadata", True)
#
# File c:\Users\ZENBOOK\anaconda3\envs\soma\lib\site-packages\unstructured\chunking\dispatch.py:74, in add_chunking_strategy.<locals>.wrapper(*args, **kwargs)
#      71 """The decorated function is replaced with this one."""
#      73 # -- call the partitioning function to get the elements --
# ---> 74 elements = func(*args, **kwargs)
#      76 # -- look for a chunking-strategy argument --
#      77 call_args = get_call_args_applying_defaults(func, *args, **kwargs)
#
# File c:\Users\ZENBOOK\anaconda3\envs\soma\lib\site-packages\unstructured\partition\pdf.py:205, in partition_pdf(filename, file, include_page_breaks, strategy, infer_table_structure, ocr_languages, languages, include_metadata, metadata_filename, metadata_last_modified, chunking_strategy, hi_res_model_name, extract_images_in_pdf, extract_image_block_types, extract_image_block_output_dir, extract_image_block_to_payload, date_from_file_object, starting_page_number, extract_forms, form_extraction_skip_tables, **kwargs)
#     201 exactly_one(filename=filename, file=file)
#     203 languages = check_language_args(languages or [], ocr_languages)
# --> 205 return partition_pdf_or_image(
#     206     filename=filename,
#     207     file=file,
#     208     include_page_breaks=include_page_breaks,
#     209     strategy=strategy,
#     210     infer_table_structure=infer_table_structure,
#     211     languages=languages,
#     212     metadata_last_modified=metadata_last_modified,
#     213     hi_res_model_name=hi_res_model_name,
#     214     extract_images_in_pdf=extract_images_in_pdf,
#     215     extract_image_block_types=extract_image_block_types,
#     216     extract_image_block_output_dir=extract_image_block_output_dir,
#     217     extract_image_block_to_payload=extract_image_block_to_payload,
#     218     date_from_file_object=date_from_file_object,
#     219     starting_page_number=starting_page_number,
#     220     extract_forms=extract_forms,
#     221     form_extraction_skip_tables=form_extraction_skip_tables,
#     222     **kwargs,
#     223 )
#
# File c:\Users\ZENBOOK\anaconda3\envs\soma\lib\site-packages\unstructured\partition\pdf.py:341, in partition_pdf_or_image(filename, file, is_image, include_page_breaks, strategy, infer_table_structure, languages, metadata_last_modified, hi_res_model_name, extract_images_in_pdf, extract_image_block_types, extract_image_block_output_dir, extract_image_block_to_payload, date_from_file_object, starting_page_number, extract_forms, form_extraction_skip_tables, **kwargs)
#     338 elif strategy == PartitionStrategy.OCR_ONLY:
#     339     # NOTE(robinson): Catches file conversion warnings when running with PDFs
#     340     with warnings.catch_warnings():
# --> 341         elements = _partition_pdf_or_image_with_ocr(
#     342             filename=filename,
#     343             file=file,
#     344             include_page_breaks=include_page_breaks,
#     345             languages=languages,
#     346             ocr_languages=ocr_languages,
#     347             is_image=is_image,
#     348             metadata_last_modified=metadata_last_modified or last_modification_date,
#     349             starting_page_number=starting_page_number,
#     350             **kwargs,
#     351         )
#     352         out_elements = _process_uncategorized_text_elements(elements)
#     354 return out_elements
#
# File c:\Users\ZENBOOK\anaconda3\envs\soma\lib\site-packages\unstructured\partition\pdf.py:882, in _partition_pdf_or_image_with_ocr(filename, file, include_page_breaks, languages, ocr_languages, is_image, metadata_last_modified, starting_page_number, **kwargs)
#     880         elements.extend(page_elements)
#     881 else:
# --> 882     for page_number, image in enumerate(
#     883         convert_pdf_to_images(filename, file), start=starting_page_number
#     884     ):
#     885         page_elements = _partition_pdf_or_image_with_ocr_from_image(
#     886             image=image,
#     887             languages=languages,
#    (...)
#     892             **kwargs,
#     893         )
#     894         elements.extend(page_elements)
#
# File c:\Users\ZENBOOK\anaconda3\envs\soma\lib\site-packages\unstructured\partition\pdf_image\pdf_image_utils.py:404, in convert_pdf_to_images(filename, file, chunk_size)
#     402 else:
#     403     f_bytes = None
# --> 404     info = pdf2image.pdfinfo_from_path(filename)
#     406 total_pages = info["Pages"]
#     407 for start_page in range(1, total_pages + 1, chunk_size):
#
# File c:\Users\ZENBOOK\anaconda3\envs\soma\lib\site-packages\pdf2image\pdf2image.py:607, in pdfinfo_from_path(pdf_path, userpw, ownerpw, poppler_path, rawdates, timeout, first_page, last_page)
#     604     return d
#     606 except OSError:
# --> 607     raise PDFInfoNotInstalledError(
#     608         "Unable to get page count. Is poppler installed and in PATH?"
#     609     )
#     610 except ValueError:
#     611     raise PDFPageCountError(
#     612         f"Unable to get page count.\n{err.decode('utf8', 'ignore')}"
#     613     )
#
# PDFInfoNotInstalledError: Unable to get page count. Is poppler installed and in PATH?

# %%
from collections import Counter
display(Counter(type(element) for element in elements))
print("")
# The composition of elements can be different for elements derived with the "fast" strategy
display(Counter(type(element) for element in elements_fast))
# Out:
# Counter({unstructured.documents.elements.Text: 21,
#          unstructured.documents.elements.NarrativeText: 4,
#          unstructured.documents.elements.Title: 3,
#          unstructured.documents.elements.Header: 1,
#          unstructured.documents.elements.Footer: 1})
# Counter({unstructured.documents.elements.Text: 21,
#          unstructured.documents.elements.NarrativeText: 4,
#          unstructured.documents.elements.Title: 3,
#          unstructured.documents.elements.Header: 1,
#          unstructured.documents.elements.Footer: 1})

# %%
display(*[(type(element), element.text) for element in elements[10:13]])
# Out:
# (unstructured.documents.elements.Text,
#  '(cid:55)(cid:49)(cid:55)(cid:3)(cid:51)(cid:53)(cid:36)(cid:58)(cid:49)(cid:54)(cid:3) (cid:55)(cid:76)(cid:74)(cid:72)(cid:85)(cid:3)(cid:83)(cid:85)(cid:68)(cid:90)(cid:81)(cid:86)(cid:3)(cid:76)(cid:81)(cid:3)(cid:87)(cid:72)(cid:80)(cid:83)(cid:88)(cid:85)(cid:68)(cid:3)(cid:69)(cid:68)(cid:87)(cid:87)(cid:72)(cid:85)(cid:3)(cid:90)(cid:76)(cid:87)(cid:75)(cid:3)(cid:55)(cid:49)(cid:55)(cid:3)(cid:86)(cid:68)(cid:88)(cid:70)(cid:72) (Supplement of €(cid:27))')
# 2 Courses €(cid:22)(cid:28) / 3 courses €(cid:23)(cid:24) Add fr(cid:442)(cid:442)(cid:3)(cid:738)owing of house wine or cava for €17.50 per person
#
# To be enjoyed with a minimum of two courses per person beginning from when your food order is taken. It is available for the alloted time of your reservation. We are happy to provide information pertaining to allergens and intolerance on request. V - vegetarian, VG - vegan

# %%
import os

from unstructured_client import UnstructuredClient
from unstructured_client.models import shared
from unstructured_client.models.errors import SDKError

client = UnstructuredClient(
    api_key_auth=os.getenv("UNSTRUCTURED_API_KEY"),
    server_url=os.getenv("UNSTRUCTURED_API_URL"),
)

filename = "../../data/The Merchants.pdf"
file = open(filename, "rb")
req = shared.PartitionParameters(
    # Note that this currently only supports a single file
    files=shared.Files(
        content=file.read(),
        file_name=filename,
    ),
    strategy=shared.Strategy.OCR_ONLY,
    languages=["eng"],
    split_pdf_page=True,
    split_pdf_allow_failed=True,
    split_pdf_concurrency_level=15
)

try:
    res = client.general.partition(req)
    print(res.elements[0])
except SDKError as e:
    print(e)
# Out:
# INFO: Preparing to split document for partition.
# INFO: Starting page number set to 1
# INFO: Allow failed set to 1
# INFO: Concurrency level set to 15
# INFO: Splitting pages 1 to 1 (1 total)
# INFO: Determined optimal split size of 2 pages.
# INFO: Document has too few pages (1) to be split efficiently. Partitioning without split.
# {'type': 'Title', 'element_id': '3089f82c45e8e26409ed9cabd911ab84', 'text': 'SUNDAY ROAST SET MENU', 'metadata': {'filetype': 'application/pdf', 'languages': ['eng'], 'page_number': 1, 'filename': 'The Merchants.pdf'}}

# %%
res.elements
# Out:
# [{'type': 'Title',
#   'element_id': '3089f82c45e8e26409ed9cabd911ab84',
#   'text': 'SUNDAY ROAST SET MENU',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': '0511964e7e5d58b160d7845764d029a5',
#   'text': 'STARTERS & SHARING',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': '8b3750007f8f1b00be82b97c235c04c6',
#   'text': 'LOBSTER & PRAWNS CROQUETAS',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': '2d47a585cd30f9d644a2bd5aa4c5560d',
#   'text': 'PEAR & GOAT CHEESE',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'NarrativeText',
#   'element_id': 'c5ac95f35563cd15f30b3371dd79aa20',
#   'text': 'Watercress, rocket, garlic, balsamic, honey, almonds, onion marmelade',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'parent_id': '2d47a585cd30f9d644a2bd5aa4c5560d',
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': '635ab1df52357b27ad27deaba9f3fd41',
#   'text': 'Avocado puree, TNT sauce',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': '79a29133e2c8598d2d0df280bc74955a',
#   'text': 'GRILLED LAMB CUTLETS',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': 'ae4847b30d3d66a9bb53066c3d02aa27',
#   'text': 'ROASTED PUMPKIN & COCONUT SOUP',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'UncategorizedText',
#   'element_id': '1bdffe4deddaa87442573d37c2d694a9',
#   'text': 'Sesame oil, sriracha, soy, pistachio, blood orange gel,',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'parent_id': 'ae4847b30d3d66a9bb53066c3d02aa27',
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': 'cc010bcba2266eb096df1ce756947d77',
#   'text': 'Crunchy pumpkin seeds',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': '4837eaf8e6ca9f43de91d27cc965837f',
#   'text': 'pomegranate',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': '261b874c6f2a02bf6dfed9656bc86d43',
#   'text': 'EGGS BENEDICT',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': 'd986fa8142d70d0307c9b5a30c117ed7',
#   'text': 'SMASHED AVOCADO ON TOAST & EGGS',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': '7fba90905317f1b2198ecb54d48ea95e',
#   'text': 'Holandaise sauce with spinach or ham',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': '093259d2260a6a6b8882769605b4e90a',
#   'text': 'Poached eggs, sourdough & red chillies',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': '1931c02ea5e8ba7352f36bd8f4713e0c',
#   'text': 'Tiger prawns in tempura batter with TNT sauce',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': '7ef61c04911a63334b9c5359c4ac4006',
#   'text': '(Supplement of €8)',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': '465bcb9ab38111f5f14433ac8a965e7a',
#   'text': 'MAIN COURSE',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': 'ce395ca8886111f6160f1f77ee61c59d',
#   'text': 'JUICY LUCY BURGER',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': '66d4d469996c24b725d3728e2be3ad13',
#   'text': 'PAN FRIED DUCK BREAST',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': 'cc23fbffe1430161125795dbc4f217a5',
#   'text': 'Stuffed cheddar cheese patty, bacon',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'UncategorizedText',
#   'element_id': 'e894770e4f54e1aaccc671f459694666',
#   'text': 'Butternut squash puree, plum & cranberry sauce,',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'parent_id': 'cc23fbffe1430161125795dbc4f217a5',
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': '2254168451defb27c7a5f7dc22368ebb',
#   'text': 'tomato & pickles',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': '47b782896abe15cbfc593f1cc01ad443',
#   'text': 'baby carrots',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': 'a7b227dc848d6b9981bd74de7e29dda5',
#   'text': 'GRILLED SALMON',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': '23dc44b22d2308ce3ec153c0371bec2d',
#   'text': 'VEGAN CAULIFLOWER STEAK',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': '2dfce53874adbbfe5bb95e48b25b03e4',
#   'text': 'Miso, honey, lemon, watercress, spinach, salmon roe',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': '70f446bc8313695e004c497b7eb3fb29',
#   'text': 'Seasonal mushroom gravy, chia & pistacchio seeds',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': 'dfa49b39c161761867ddfa3a805453be',
#   'text': 'SUNDAY ROAST',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'NarrativeText',
#   'element_id': 'fc2d47fa38923a41f280ccfda701d467',
#   'text': '(Served with potatoes, vegetables, Yorkshire pudding & gravy)',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'parent_id': 'dfa49b39c161761867ddfa3a805453be',
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': '05670abd6f74c14f877dd1543ddd674a',
#   'text': 'PORK BELLY',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': '6f3884cb64f4ae6d206168fa8bcb63e2',
#   'text': 'ROASTED SIRLOIN CORNFED CHICKEN',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': 'ca38a3a7cd326af7a6f853d27cc2d2b0',
#   'text': 'REEF & BEEF',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': '770d123989020c0c773aad96eec15d75',
#   'text': '3409 Ribeye steak, half Canadian lobster, fries, salad & Garlic',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': 'f161c619e79da0c0f235c6ee0e7bd6d1',
#   'text': 'Supplement of €45',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': '2c4796ca2c1e209a1fd8047959ffe9f2',
#   'text': 'SIDES & SAUCES',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'NarrativeText',
#   'element_id': 'ce6054961da22981ff4f1cef5269cb25',
#   'text': '(Supplement charges apply on brunch menu)',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'parent_id': '2c4796ca2c1e209a1fd8047959ffe9f2',
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': '0e462cb3ed6010c779ee8639aa27dc92',
#   'text': 'CHAMP MASH POTATOES - €7.00',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': '9adc37153feafdd038aad1ef8c95908d',
#   'text': 'GARDEN SALAD - €7.00',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': 'dd7eed935da4851a2f22322bb7a3f024',
#   'text': 'FRIES WITH TRUFFLE AND PARMESAN - €7.00',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': '3b75e0211167789d9ffecef8d5a72fc1',
#   'text': 'SAUCES - €3.50 (Peppecorn, Chimichurri, Bernaise , Blue cheese)',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': 'cb1c6eaff4ea7cdf9a69bd2915c8af56',
#   'text': 'DESSERTS',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': '5291d2326aaa829a4f5b57eafb4db1aa',
#   'text': 'S’MORES',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': '7e9afdb8ad701ae68f7fcccf59c7972b',
#   'text': 'APPLE & RASPBERRY CRUMBLE',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'Title',
#   'element_id': '74e879a035ef4901e071db4f47ab4860',
#   'text': 'SELECTION OF ICE CREAMS & SORBETS',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'NarrativeText',
#   'element_id': '5b0e1b0087ea8f6d3d8c6cde6411666a',
#   'text': 'To be enjoyed with a minimum of two courses per person beginning from when your food order is taken.',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'parent_id': '74e879a035ef4901e071db4f47ab4860',
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'NarrativeText',
#   'element_id': '5c4d0a5d482d8524eb64c73b2e6812cb',
#   'text': 'It is available for the alloted time of your reservation.',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'parent_id': '74e879a035ef4901e071db4f47ab4860',
#    'filename': 'The Merchants.pdf'}},
#  {'type': 'NarrativeText',
#   'element_id': '39b1119b93373dc23545e759541b8143',
#   'text': 'We are happy to provide information pertaining to allergens and intolerance on request. V - vegetarian, VG - vegan',
#   'metadata': {'filetype': 'application/pdf',
#    'languages': ['eng'],
#    'page_number': 1,
#    'parent_id': '74e879a035ef4901e071db4f47ab4860',
#    'filename': 'The Merchants.pdf'}}]

# %%
import PyPDF2

# creating a pdf reader object
reader = PyPDF2.PdfReader('../../data/The Merchants.pdf')

# print the number of pages in pdf file
print(len(reader.pages))

# print the text of the first page
print(reader.pages[0].extract_text())
# Out:
# 1
# STARTERS & SHARING
# MAIN COURSE
# To be enjoyed with a minimum of two courses per person beginning from when your food order is taken.
# It is available for the alloted time of your reservation.
# We are happy to provide information pertaining to allergens and intolerance on request. V - vegetarian, VG - vegan-8,&</8&<%85*(5
# 6WXIIHGFKHGGDUFKHHVHSDWW\EDFRQ
# WRPDWR	SLFNOHV
# 6·025(6
# $33/(	5$63%(55<&580%/(
# 6(/(&7,212),&(&5($06	625%(76
# 2 Courses € / 3 courses €
# Add frƺƺˢowing of house wine or cava for €17.50 per personCHAMP MASH POT ATOES - €
# GARDEN SALAD - €
# FRIES WITH TRUFFLE AND PARMESAN - €
# SAUCES - €3. ( Peppecorn, Chimichurri, Bernaise , Blue cheese)
# DESSERTS340g Ribeye steak, half Canadian lobster, f ries, salad & Garlic
# (Supplement of €)325.%(//<  52$67('6,5/2,1
# 5(()	%(()681'$<52$67
# (Served with potatoes, vegetables, Yorkshire pudding & gravy)
# SIDES & SAUCES
# (Supplement charges apply on brunch menu)3($5	*2$7 &+((6(
# :DWHUFUHVVURFNHWJDUOLFEDOVDPLFKRQH\DOPRQGVRQLRQPDUPHODGH
# 52$67('3803.,1	&2&21876283
# &UXQFK\SXPSNLQVHHGV
# 60$6+('$92&$' 22172$67 	(**6
# 3RDFKHGHJJVVRXUGRXJK	UHGFKLOOLHV/2%67(5	35$:16&5248(7$6
# $YRFDGRSXUHH717VDXFH
# *5,//('/$0%&87/(76
# 6HVDPHRLOVULUDFKDVR\SLVWDFKLREORRGRUDQJHJHO
# SRPHJUDQDWH
# (**6%(1(',&7
# +RODQGDLVHVDXFHZLWKVSLQDFKRUKDPSUNDAY ROAST SET MENU
# 0LVRKRQH\OHPRQZDWHUFUHVVVSLQDFKVDOPRQURH*5,//('6$/0213$1)5,(''8&.%5($67
# %XWWHUQXWVTXDVKSXUHHSOXP	FUDQEHUU\VDXFH
# EDE\FDUURWV
# 9(*$1&$8/,)/2:(567($.
# 6HDVRQDOPXVKURRPJUDY\FKLD	SLVWDFFKLRVHHGV
# &251)('&+,&.(171735$:167LJHUSUDZQVLQWHPSXUDEDWWHUZLWK717VDXFH
# (Supplement of € )

# %%
from langchain_community.document_loaders import UnstructuredPDFLoader
from langchain_community.document_loaders import OnlinePDFLoader
local_path = "../../data/Bodeguilla.pdf"

# Local PDF file uploads
if local_path:
  loader = UnstructuredPDFLoader(file_path=local_path)
  data = loader.load()
else:
  print("Upload a PDF file")

# %%
print(data[0].page_content)
# Out:
# M A L L O R Q U Í
#
# Tapes —
#
# Pernil ibèric de gla Juan Manuel D.O. Guijuelo (80g)
#
# Cecina de bou, esparrecs, formatge Roncal i oli d’amontillat
#
# Ostra Regal Special nº2 al natural (u.)
#
# Ostra amb gaspatxo blanc de meló (u.)
#
# Ostra a sa brasa amb gamba vermella a l’all
#
# Carpaccio de gamba vermella, fonoll marí i emulsió de ses caps
#
# Tàrtar de tonyina, tomàtiga, alvocat a sa brasa i algues
#
# Steak tartar de vedella vella de muntanya
#
# Ensaladilla tradicional de patata amb gamba y mahonesa
#
# Burrata, albergínia rostida, tomàtigues escalivades i llimona
#
# Amanida de tomàtigues de temporada, all verd de pinyons i bacallà
#
# Espàrrecs verds a sa brasa amb romesco casolà i salsa tàrtara
#
# Les Braves de La Bodeguilla
#
# Ou a baixa temperatura amb salsa de foie i trufa fresca
#
# Croquetes meloses de pernil de Guijuelo (6u.)
#
# Zamburinyes amb picadillo i vinagre de Chardonnay (6u.)
#
# Calamars fregits amb allioli de prebes de Padró
#
# Fideuà de carrabiner i allioli dels seus corals
#
# Pop rostit amb ou, papada ibèrica i patata a s’all
#
# Caneló de pollastre camperol, salsa de trompetes i poma
#
# Ploma ibèrica a sa brasa, porro fumat, mostassa i festucs
#
# 26.00€
#
# 19.50€
#
# 4.85€
#
# 6.50€
#
# 7.50€
#
# 26.00€
#
# 24.50€
#
# 23.50€
#
# 18.00€
#
# 21.00€
#
# 19.00€
#
# 18.50€
#
# 16.50€
#
# 18.50€
#
# 18.00€
#
# 19.50€
#
# 22.50€
#
# 27.50€
#
# 28.00€
#
# 22.00€
#
# 29.00€
#
# Arrossos i Peixos —
#
# Carns —
#
# Arròs del ‘Senyoret’ amb vieira, gamba vermella i calamà
#
# Caldereta de llamàntol amb arròs Acuarello ecològic (mín 2 pax) (preu per persona)
#
# Llobarro a sa brasa amb mallorquina de verdures i salsa de mantega d’algues
#
# Llom de tonyina al Josper, albergínia rostida, oliva kalamata i piparres
#
# Llamàntol a sa brasa amb alls i bitxo amb patates fregides i pebres de Padron
#
# Porcella mallorquina de porc negre al forn amb pata- tes forneres i brots verds
#
# Espatlla de xai de llet rostida amb mel i romaní, patates forneres i brots verds
#
# Filet de vaca seleccionada (250gr), salsa de pebre i mil- fulles de patata
#
# Costelles de xai a sa brasa amb all i romaní amb patates fregides i pebres de Padron
#
# Txuleta de vaca seleccionada reposada a sa brasa (amb piquillos i patates fregides) (ideal per compartir)(preu per kg)
#
# Servei de pa, oli d’oliva verge extra ecològic i olives amanides 3.50€ per persona Allioli 3.75€ Pa amb tomàtiga i oli d’oliva verge extra 7.85€
#
# * TOTS ELS PREUS INDICATS SÓN AMB IVA INCLÒS
#
# M A L L O R Q U Í
#
# 29.00€
#
# 42.00€
#
# 38.50€
#
# 36.00€
#
# 39.00€
#
# 36.00€
#
# 39.00€
#
# 38.00€
#
# 36.00€
#
# 85.00€
#
# E S P A Ñ O L
#
# Tapas —
#
# Jamón ibérico de bellota Juan Manuel D.O. Guijuelo (80g)
#
# Cecina de vaca, trigueros, queso Roncal y aceite de amontillado
#
# Ostra Regal Special nº2 al natural (u.)
#
# Ostra con gazpacho blanco de melón (u.)
#
# Ostra a la brasa con gamba roja al ajillo
#
# Carpaccio de gamba roja, hinojo marino y emulsión de sus cabezas
#
# Tartar de atún, tomate, aguacate a la brasa y algas
#
# Steak tartar de solomillo de vaca vieja
#
# Ensaladilla tradicional de patata con gambita frita y mahonesa
#
# Burrata, berenjena asada, tomates escalivados y limón en salmuera
#
# Ensalada de tomate de temporada, ajo verde de pistacho y bacalao
#
# Espárragos verdes a la brasa con romescu casero y salsa tártara
#
# Las Bravas de La Bodeguilla
#
# Huevo escalfado con foie y trufa fresca
#
# Croquetas melosas de jamón de Guijuelo (6u.)
#
# Zamburiñas con picadillo de vinagre de chardonnay (6u.)
#
# Calamares fritos con alioli de pimientos de Padrón
#
# Fideuà de carabinero y alioli de sus corales
#
# Pulpo asado con huevo, papada ibérica y patata al ajo
#
# Canelón de pollo campero, salsa de trompetas y manzana
#
# Pluma ibérica a la brasa, puerro ahumado, mostaza y pistachos
#
# 26.00€
#
# 19.50€
#
# 4.85€
#
# 6.50€
#
# 7.50€
#
# 26.00€
#
# 24.50€
#
# 23.50€
#
# 18.00€
#
# 21.00€
#
# 19.00€
#
# 18.50€
#
# 16.50€
#
# 18.50€
#
# 18.00€
#
# 19.50€
#
# 22.50€
#
# 27.50€
#
# 28.00€
#
# 22.00€
#
# 29.00€
#
# Arroces y Pescados —
#
# Carnes —
#
# Arroz del ‘‘Senyoret’’ con vieira, gamba roja y calamar
#
# Caldereta de bogavante con arroz Acuarello (mín 2 pax) (precio por persona)
#
# Lubina a la brasa con verduras a la mallorquina y salsa de mantequilla de algas
#
# Lomo de atún al Josper, berenjena asada, aceituna kalamata y piparras
#
# Bogavante a la brasa con ajos y guindilla, patatas fritas y pimientos de Padrón
#
# Cochinillo mallorquín de “porc negre” al horno con patatas panaderas y brotes verdes
#
# Paletilla de cordero lechal asada con miel y romero, patatas panaderas y brotes verdes
#
# Solomillo de vaca seleccionada (250gr ), salsa de pimienta verde y milhojas de patata
#
# Costillas de cordero a la brasa con ajo y romero patatas fritas y pimientos de Padrón
#
# Txuleta de vaca seleccionada reposada a la brasa (con pimientos de piquillo y patatas fritas) (ideal para compartir)(precio por kg)
#
# Servicio de pan, aceite de oliva virgen extra ecológico y aceitunas aliñadas 3.50€ por persona Alioli 3.75€ Pan con tomate y aceite de oliva virgen extra 7.85€
#
# *TODOS LOS PRECIOS INDICADOS SON CON IVA INCLUÍDO
#
# E S P A Ñ O L
#
# 29.00€
#
# 42.00€
#
# 38.50€
#
# 36.00€
#
# 39.00€
#
# 36.00€
#
# 39.00€
#
# 38.00€
#
# 36.00€
#
# 85.00€
#
# E N G L I S H
#
# Tapas —
#
# Iberian cured ham Juan Manuel Guijuelo (80g)
#
# ‘‘Cecina’’ cured beef, Roncal cheese and amontillado oil
#
# Regal nº2 Natural oyster (u.)
#
# Oyster with white melon gazpacho (u.)
#
# Grilled oyster with red prawn in light garlic sauce (u.)
#
# Carpaccio of red prawns, sea fennel and emulsion of their heads
#
# Tuna tartar, tomato, grilled avocado and seaweed
#
# Sirloin steak tartare
#
# Traditional potato salad with shrimps and mayonaise
#
# Burrata, roasted eggplant, tomatoes and lemon in brine
#
# Seasonal tomato salad, pistachio green garlic and El Barquero cod
#
# Char-grilled green asparagus with romescu and tartar sauce
#
# La Bodeguilla’s brava potatoes
#
# Low-temperature egg with a foie and truffle sauce
#
# Cured ham croquettes (6u.)
#
# ‘‘Zamburiñas’’ Scallops with ‘‘picadillo’’ & chardonnay vinegar (6u.)
#
# Deep-fried calamari with ‘‘Padron’’ peppers ‘‘allioli’’
#
# Fideuà of scarlet shrimp and aioli from its corals
#
# Roast octopus with egg, Iberian jowls and garlic potato
#
# Cannelloni stuffed with free-range chicken and mushroom sauce
#
# Grilled Iberian pork shoulder, smoked leeks and mustard
#
# 26.00€
#
# 19.50€
#
# 4.85€
#
# 6.50€
#
# 7.50€
#
# 26.00€
#
# 24.50€
#
# 23.50€
#
# 18.00€
#
# 21.00€
#
# 19.00€
#
# 18.50€
#
# 16.50€
#
# 18.50€
#
# 18.00€
#
# 19.50€
#
# 22.50€
#
# 27.50€
#
# 28.00€
#
# 22.00€
#
# 29.00€
#
# Rice & Fish —
#
# Meats —
#
# ‘‘Senyoret’’ rice with scallop, red shrimp and squid
#
# Lobster stew with Acuarello eco rice (min 2 pax) (price per person)
#
# Grilled sea bass with vegetables Mallorcan seaweed butter sauce
#
# Josper-cooked tuna loin, roasted eggplant, kalamata olives and ‘‘piparras’’
#
# Grilled lobster with garlic and chilli with french fries and Padrón peppers
#
# La Bodeguilla’s roast suckling pig (Majorcan black pig) with panadera potatoes and green salad
#
# Roast Majorcan lamb shoulder with honey and rosemary, panadera potatoes and green salad
#
# Josper-cooked fillet steak (250gr), green pepper sauce and potato millefeuille
#
# Grilled lamb ribs with garlic and rosemary with french fries and Padrón peppers
#
# Char-grilled Premium beef chop (with piquillo peppers and french fries) (ideal to share)(price per kg)
#
# Bread service, organic extra virgin olive oil and seasoned olives €3.50 per person ‘‘Allioli’’ €3.75 Bread with tomato and extra virgin olive oil €7.85
#
# *ALL PRICES INDICATED ARE WITH V.A.T. INCLUDED
#
# E N G L I S H
#
# 29.00€
#
# 42.00€
#
# 38.50€
#
# 36.00€
#
# 39.00€
#
# 36.00€
#
# 39.00€
#
# 38.00€
#
# 36.00€
#
# 85.00€
#
# D E U T S C H
#
# Tapas —
#
# Ibérico-Shinken aus Eichelmast Juan Manuel, D.O Guijuelo (80g)
#
# Getrocknetes Rindfleisch, Roncal-Käse und Amontillado-Öl
#
# Regal nº2 Natural Austern (St.)
#
# Auster mit Melonengazpacho (St.)
#
# Gegrillte Auster mit roten Garnelen eingelegt in Knoblauch (St.)
#
# Garnelencarpaccio, Kopfemulsion und Seefenchel
#
# Thunfisch-Tartar mit Tomate, gegrillte Avocado und Seetang
#
# Rindertatar mit grünem Senf und Käse
#
# Spanischer Bratkartoffelsalat mit gebratenen Garnelen und mayo
#
# Burrata, geröstete Auberginen, Tomaten und Zitrone in Salzlake
#
# Tomaten Salat, Pistazien, Knoblauch und Kabeljau ‘‘El Barquero’’
#
# Gegrillter grüner Spargel mit Romescu und Remoulade
#
# Kartoffelecken ‘‘La Bodeguilla’’
#
# Pochiertes Ei mit Foie-Gras Sauce und Trüffel
#
# Schinken Kroketten (6St.)
#
# Jakobsmuscheln mit knoblauch, petersilie und weissweinessig (6St.)
#
# Gebratener Tintenfisch mit ‘‘Padrón’’-paprika mayonnaise
#
# Fideuà aus scharlachroten Garnelen und Aioli aus seinen Korallen
#
# Gebratener Oktopus mit Ei, iberischer Wamme, Knoblauchkartoffel
#
# Canelloni vom Freilanhähnchen mit Trichterling-Apfel-Sauce
#
# Gegrillter Iberico-Schweinerücken geräucherter Lauch und Pistazien
#
# 26.00€
#
# 19.50€
#
# 4.85€
#
# 6.50€
#
# 7.50€
#
# 26.00€
#
# 24.50€
#
# 23.50€
#
# 18.00€
#
# 21.00€
#
# 19.00€
#
# 18.50€
#
# 16.50€
#
# 18.50€
#
# 18.00€
#
# 19.50€
#
# 22.50€
#
# 27.50€
#
# 28.00€
#
# 22.00€
#
# 29.00€
#
# Reis & Fisch —
#
# Fleisch —
#
# ‘Senyoret’ Reis mit Jakobsmuschel rote Garnelen und Tintenfisch
#
# Hummereintopf mit Acuarello reis ökologisch (min. 2 Personen) (Preis pro Person)
#
# Gegrillter Wolfsbarsch mit Gemüse Mallorquinisch und Algenbuttersauce
#
# Josper-Thunfischlende, geröstete Auberginen, Kalamata-Oliven und ‘‘Piparras’’
#
# Gebratener Hummer mit Knoblauch und Chili mit Pommes frites und Padrón-Paprika
#
# Spanferkel vom mallorquinischen schwarzen Schwein mit Bäckerinkartoffeln grüner Salat
#
# Geschmorte Lammschulter mit Honig und Rosmarin und Bäckerinkartoffeln grüner Salat
#
# Ausgewähltes Rinderfilet (250gr), grüne Pfeffersauce und Kartoffel-Millefeuille
#
# Gegrillte Lammrippchen mit Knoblauch und Rosmarin mit Pommes frites und Padrón-Paprika
#
# Gegrilltes Premium Rinderkotelett (mit “piquillo” Paprika und Pommes frites) (ideal zum Teilen) (Preis pro kg)
#
# Brötchenservice, Bio-Olivenöl extra vergine und gewürzte Oliven 3,50 € pro Person Aioli 3,75 € Brot mit Tomaten und nativem Olivenöl extra 7,85 €
#
# *ALLE ANGEGEBENEN PREISE VERSTEHEN SICH INKLUSIVE MEHRWERTSTEUER
#
# D E U T S C H
#
# 29.00€
#
# 42.00€
#
# 38.50€
#
# 36.00€
#
# 39.00€
#
# 36.00€
#
# 39.00€
#
# 38.00€
#
# 36.00€
#
# 85.00€
#
# LA-BODEGUILLA
#
# LABODEGUILLA1986

# %%
import re
def cidToChar(cidx):
    return chr(int(re.findall(r'\(cid\:(\d+)\)',cidx)[0]) + 29)

# %%
txt = ""
for x in data[0].page_content.split('\n'):
  if x != '' and x != '(cid:3)':         # merely to compact the output
    abc = re.findall(r'\(cid\:\d+\)',x)
    if len(abc) > 0:
        for cid in abc: x=x.replace(cid, cidToChar(cid))
    txt = txt+"\n"+repr(x).strip("'")

# %%
print(txt)
# Out:
# M A L L O R Q U Í
# Tapes —
# Pernil ibèric de gla Juan Manuel D.O. Guijuelo (80g)
# Cecina de bou, esparrecs, formatge Roncal i oli d’amontillat
# Ostra Regal Special nº2 al natural (u.)
# Ostra amb gaspatxo blanc de meló (u.)
# Ostra a sa brasa amb gamba vermella a l’all
# Carpaccio de gamba vermella, fonoll marí i emulsió de ses caps
# Tàrtar de tonyina, tomàtiga, alvocat a sa brasa i algues
# Steak tartar de vedella vella de muntanya
# Ensaladilla tradicional de patata amb gamba y mahonesa
# Burrata, albergínia rostida, tomàtigues escalivades i llimona
# Amanida de tomàtigues de temporada, all verd de pinyons i bacallà
# Espàrrecs verds a sa brasa amb romesco casolà i salsa tàrtara
# Les Braves de La Bodeguilla
# Ou a baixa temperatura amb salsa de foie i trufa fresca
# Croquetes meloses de pernil de Guijuelo (6u.)
# Zamburinyes amb picadillo i vinagre de Chardonnay (6u.)
# Calamars fregits amb allioli de prebes de Padró
# Fideuà de carrabiner i allioli dels seus corals
# Pop rostit amb ou, papada ibèrica i patata a s’all
# Caneló de pollastre camperol, salsa de trompetes i poma
# Ploma ibèrica a sa brasa, porro fumat, mostassa i festucs
# 26.00€
# 19.50€
# 4.85€
# 6.50€
# 7.50€
# 26.00€
# 24.50€
# 23.50€
# 18.00€
# 21.00€
# 19.00€
# 18.50€
# 16.50€
# 18.50€
# 18.00€
# 19.50€
# 22.50€
# 27.50€
# 28.00€
# 22.00€
# 29.00€
# Arrossos i Peixos —
# Carns —
# Arròs del ‘Senyoret’ amb vieira, gamba vermella i calamà
# Caldereta de llamàntol amb arròs Acuarello ecològic (mín 2 pax) (preu per persona)
# Llobarro a sa brasa amb mallorquina de verdures i salsa de mantega d’algues
# Llom de tonyina al Josper, albergínia rostida, oliva kalamata i piparres
# Llamàntol a sa brasa amb alls i bitxo amb patates fregides i pebres de Padron
# Porcella mallorquina de porc negre al forn amb pata- tes forneres i brots verds
# Espatlla de xai de llet rostida amb mel i romaní, patates forneres i brots verds
# Filet de vaca seleccionada (250gr), salsa de pebre i mil- fulles de patata
# Costelles de xai a sa brasa amb all i romaní amb patates fregides i pebres de Padron
# Txuleta de vaca seleccionada reposada a sa brasa (amb piquillos i patates fregides) (ideal per compartir)(preu per kg)
# Servei de pa, oli d’oliva verge extra ecològic i olives amanides 3.50€ per persona Allioli 3.75€ Pa amb tomàtiga i oli d’oliva verge extra 7.85€
# * TOTS ELS PREUS INDICATS SÓN AMB IVA INCLÒS
# M A L L O R Q U Í
# 29.00€
# 42.00€
# 38.50€
# 36.00€
# 39.00€
# 36.00€
# 39.00€
# 38.00€
# 36.00€
# 85.00€
# E S P A Ñ O L
# Tapas —
# Jamón ibérico de bellota Juan Manuel D.O. Guijuelo (80g)
# Cecina de vaca, trigueros, queso Roncal y aceite de amontillado
# Ostra Regal Special nº2 al natural (u.)
# Ostra con gazpacho blanco de melón (u.)
# Ostra a la brasa con gamba roja al ajillo
# Carpaccio de gamba roja, hinojo marino y emulsión de sus cabezas
# Tartar de atún, tomate, aguacate a la brasa y algas
# Steak tartar de solomillo de vaca vieja
# Ensaladilla tradicional de patata con gambita frita y mahonesa
# Burrata, berenjena asada, tomates escalivados y limón en salmuera
# Ensalada de tomate de temporada, ajo verde de pistacho y bacalao
# Espárragos verdes a la brasa con romescu casero y salsa tártara
# Las Bravas de La Bodeguilla
# Huevo escalfado con foie y trufa fresca
# Croquetas melosas de jamón de Guijuelo (6u.)
# Zamburiñas con picadillo de vinagre de chardonnay (6u.)
# Calamares fritos con alioli de pimientos de Padrón
# Fideuà de carabinero y alioli de sus corales
# Pulpo asado con huevo, papada ibérica y patata al ajo
# Canelón de pollo campero, salsa de trompetas y manzana
# Pluma ibérica a la brasa, puerro ahumado, mostaza y pistachos
# 26.00€
# 19.50€
# 4.85€
# 6.50€
# 7.50€
# 26.00€
# 24.50€
# 23.50€
# 18.00€
# 21.00€
# 19.00€
# 18.50€
# 16.50€
# 18.50€
# 18.00€
# 19.50€
# 22.50€
# 27.50€
# 28.00€
# 22.00€
# 29.00€
# Arroces y Pescados —
# Carnes —
# Arroz del ‘‘Senyoret’’ con vieira, gamba roja y calamar
# Caldereta de bogavante con arroz Acuarello (mín 2 pax) (precio por persona)
# Lubina a la brasa con verduras a la mallorquina y salsa de mantequilla de algas
# Lomo de atún al Josper, berenjena asada, aceituna kalamata y piparras
# Bogavante a la brasa con ajos y guindilla, patatas fritas y pimientos de Padrón
# Cochinillo mallorquín de “porc negre” al horno con patatas panaderas y brotes verdes
# Paletilla de cordero lechal asada con miel y romero, patatas panaderas y brotes verdes
# Solomillo de vaca seleccionada (250gr ), salsa de pimienta verde y milhojas de patata
# Costillas de cordero a la brasa con ajo y romero patatas fritas y pimientos de Padrón
# Txuleta de vaca seleccionada reposada a la brasa (con pimientos de piquillo y patatas fritas) (ideal para compartir)(precio por kg)
# Servicio de pan, aceite de oliva virgen extra ecológico y aceitunas aliñadas 3.50€ por persona Alioli 3.75€ Pan con tomate y aceite de oliva virgen extra 7.85€
# *TODOS LOS PRECIOS INDICADOS SON CON IVA INCLUÍDO
# E S P A Ñ O L
# 29.00€
# 42.00€
# 38.50€
# 36.00€
# 39.00€
# 36.00€
# 39.00€
# 38.00€
# 36.00€
# 85.00€
# E N G L I S H
# Tapas —
# Iberian cured ham Juan Manuel Guijuelo (80g)
# ‘‘Cecina’’ cured beef, Roncal cheese and amontillado oil
# Regal nº2 Natural oyster (u.)
# Oyster with white melon gazpacho (u.)
# Grilled oyster with red prawn in light garlic sauce (u.)
# Carpaccio of red prawns, sea fennel and emulsion of their heads
# Tuna tartar, tomato, grilled avocado and seaweed
# Sirloin steak tartare
# Traditional potato salad with shrimps and mayonaise
# Burrata, roasted eggplant, tomatoes and lemon in brine
# Seasonal tomato salad, pistachio green garlic and El Barquero cod
# Char-grilled green asparagus with romescu and tartar sauce
# La Bodeguilla’s brava potatoes
# Low-temperature egg with a foie and truffle sauce
# Cured ham croquettes (6u.)
# ‘‘Zamburiñas’’ Scallops with ‘‘picadillo’’ & chardonnay vinegar (6u.)
# Deep-fried calamari with ‘‘Padron’’ peppers ‘‘allioli’’
# Fideuà of scarlet shrimp and aioli from its corals
# Roast octopus with egg, Iberian jowls and garlic potato
# Cannelloni stuffed with free-range chicken and mushroom sauce
# Grilled Iberian pork shoulder, smoked leeks and mustard
# 26.00€
# 19.50€
# 4.85€
# 6.50€
# 7.50€
# 26.00€
# 24.50€
# 23.50€
# 18.00€
# 21.00€
# 19.00€
# 18.50€
# 16.50€
# 18.50€
# 18.00€
# 19.50€
# 22.50€
# 27.50€
# 28.00€
# 22.00€
# 29.00€
# Rice & Fish —
# Meats —
# ‘‘Senyoret’’ rice with scallop, red shrimp and squid
# Lobster stew with Acuarello eco rice (min 2 pax) (price per person)
# Grilled sea bass with vegetables Mallorcan seaweed butter sauce
# Josper-cooked tuna loin, roasted eggplant, kalamata olives and ‘‘piparras’’
# Grilled lobster with garlic and chilli with french fries and Padrón peppers
# La Bodeguilla’s roast suckling pig (Majorcan black pig) with panadera potatoes and green salad
# Roast Majorcan lamb shoulder with honey and rosemary, panadera potatoes and green salad
# Josper-cooked fillet steak (250gr), green pepper sauce and potato millefeuille
# Grilled lamb ribs with garlic and rosemary with french fries and Padrón peppers
# Char-grilled Premium beef chop (with piquillo peppers and french fries) (ideal to share)(price per kg)
# Bread service, organic extra virgin olive oil and seasoned olives €3.50 per person ‘‘Allioli’’ €3.75 Bread with tomato and extra virgin olive oil €7.85
# *ALL PRICES INDICATED ARE WITH V.A.T. INCLUDED
# E N G L I S H
# 29.00€
# 42.00€
# 38.50€
# 36.00€
# 39.00€
# 36.00€
# 39.00€
# 38.00€
# 36.00€
# 85.00€
# D E U T S C H
# Tapas —
# Ibérico-Shinken aus Eichelmast Juan Manuel, D.O Guijuelo (80g)
# Getrocknetes Rindfleisch, Roncal-Käse und Amontillado-Öl
# Regal nº2 Natural Austern (St.)
# Auster mit Melonengazpacho (St.)
# Gegrillte Auster mit roten Garnelen eingelegt in Knoblauch (St.)
# Garnelencarpaccio, Kopfemulsion und Seefenchel
# Thunfisch-Tartar mit Tomate, gegrillte Avocado und Seetang
# Rindertatar mit grünem Senf und Käse
# Spanischer Bratkartoffelsalat mit gebratenen Garnelen und mayo
# Burrata, geröstete Auberginen, Tomaten und Zitrone in Salzlake
# Tomaten Salat, Pistazien, Knoblauch und Kabeljau ‘‘El Barquero’’
# Gegrillter grüner Spargel mit Romescu und Remoulade
# Kartoffelecken ‘‘La Bodeguilla’’
# Pochiertes Ei mit Foie-Gras Sauce und Trüffel
# Schinken Kroketten (6St.)
# Jakobsmuscheln mit knoblauch, petersilie und weissweinessig (6St.)
# Gebratener Tintenfisch mit ‘‘Padrón’’-paprika mayonnaise
# Fideuà aus scharlachroten Garnelen und Aioli aus seinen Korallen
# Gebratener Oktopus mit Ei, iberischer Wamme, Knoblauchkartoffel
# Canelloni vom Freilanhähnchen mit Trichterling-Apfel-Sauce
# Gegrillter Iberico-Schweinerücken geräucherter Lauch und Pistazien
# 26.00€
# 19.50€
# 4.85€
# 6.50€
# 7.50€
# 26.00€
# 24.50€
# 23.50€
# 18.00€
# 21.00€
# 19.00€
# 18.50€
# 16.50€
# 18.50€
# 18.00€
# 19.50€
# 22.50€
# 27.50€
# 28.00€
# 22.00€
# 29.00€
# Reis & Fisch —
# Fleisch —
# ‘Senyoret’ Reis mit Jakobsmuschel rote Garnelen und Tintenfisch
# Hummereintopf mit Acuarello reis ökologisch (min. 2 Personen) (Preis pro Person)
# Gegrillter Wolfsbarsch mit Gemüse Mallorquinisch und Algenbuttersauce
# Josper-Thunfischlende, geröstete Auberginen, Kalamata-Oliven und ‘‘Piparras’’
# Gebratener Hummer mit Knoblauch und Chili mit Pommes frites und Padrón-Paprika
# Spanferkel vom mallorquinischen schwarzen Schwein mit Bäckerinkartoffeln grüner Salat
# Geschmorte Lammschulter mit Honig und Rosmarin und Bäckerinkartoffeln grüner Salat
# Ausgewähltes Rinderfilet (250gr), grüne Pfeffersauce und Kartoffel-Millefeuille
# Gegrillte Lammrippchen mit Knoblauch und Rosmarin mit Pommes frites und Padrón-Paprika
# Gegrilltes Premium Rinderkotelett (mit “piquillo” Paprika und Pommes frites) (ideal zum Teilen) (Preis pro kg)
# Brötchenservice, Bio-Olivenöl extra vergine und gewürzte Oliven 3,50 € pro Person Aioli 3,75 € Brot mit Tomaten und nativem Olivenöl extra 7,85 €
# *ALLE ANGEGEBENEN PREISE VERSTEHEN SICH INKLUSIVE MEHRWERTSTEUER
# D E U T S C H
# 29.00€
# 42.00€
# 38.50€
# 36.00€
# 39.00€
# 36.00€
# 39.00€
# 38.00€
# 36.00€
# 85.00€
# LA-BODEGUILLA
# LABODEGUILLA1986

# %%
data[0].page_content
# Out:
# 'SUNDAY ROAST SET MENU\n\nSTARTERS & SHARING\n\n(cid:47)(cid:50)(cid:37)(cid:54)(cid:55)(cid:40)(cid:53)(cid:3)(cid:9)(cid:3)(cid:51)(cid:53)(cid:36)(cid:58)(cid:49)(cid:54)(cid:3)(cid:38)(cid:53)(cid:50)(cid:52)(cid:56)(cid:40)(cid:55)(cid:36)(cid:54)\n\n(cid:36)(cid:89)(cid:82)(cid:70)(cid:68)(cid:71)(cid:82)(cid:3)(cid:83)(cid
"Amanida de tomàtigues de temporada, all verd de pinyons i bacallà",
"Espàrrecs verds a sa brasa amb romesco casolà i salsa tàrtara",
"Les Braves de La Bodeguilla",
"Ou a baixa temperatura amb salsa de foie i trufa fresca",
"Croquetes meloses de pernil de Guijuelo (6u.)",
"Zamburinyes amb picadillo i vinagre de Chardonnay (6u.)",
"Calamars fregits amb allioli de prebes de Padró",
"Fideuà de carrabiner i allioli dels seus corals",
"Pop rostit amb ou, papada ibèrica i patata a s’all",
"Caneló de pollastre camperol, salsa de trompetes i poma",
"Ploma ibèrica a sa brasa, porro fumat, mostassa i festucs"])
# Out:
# 20

# %% [markdown]
# # Enhacement of menu

# %%
system_message_content = """
    You are a helpful assistant, expert of cutomer service for restaurants.

"""

# %%
completion = client.chat.completions.create(
    model="gpt-4o-2024-08-06",  # model supporting structured outputs
    messages=[{
        "role": "system", 
        "content": system_message_content
    },
    {
    "role": "user",
    "content": user_message_content
    }],
    response_format={
        "type": "json_schema",
        "json_schema": intermediate_step_schema
    }
)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 txt
#
# NameError: name 'txt' is not defined

# %%
# load packages
from openai import OpenAI

import json
import os
from jsonschema import validate
from jsonschema.exceptions import ValidationError

sys.path.append("../../")
# load restaurant information inputs
from inputs.restaurant_info.name import name
from inputs.restaurant_info.location import location
from inputs.restaurant_info.cuisine import cuisine
from inputs.restaurant_info.nationalities import nationalities


# load schemas
from enhance.schemas.given_menu_schema import given_menu_schema
from enhance.schemas.intermediate_step_schema import intermediate_step_schema
from enhance.schemas.enhanced_menu_schema import enhanced_menu_schema

# load functions
from enhance.validate import dish_exists, dish_exists_in_menu

client = OpenAI()

system_message_content = """
You are a helpful assistant designed to enhance restaurant menus.

# Information
You will receive prompts with, and only with, the following input information:
- ** Restaurant's Name **: a String of the name of the restaurant you are helping.
- ** Restaurant's Location **: a JSON object including the neighborhood, city, state, and country of the restaurant you are helping. 
- ** Restaurant's Cuisine **: a String of the chosen cuisine of the restaurant you are helping.
- ** Restaurant's Top Three Guest Nationalities **: an array of Strings of the top three nationalities which visit the restaurant you are helping.
- ** Restaurant's Menu(s) **: a JSON object including the category, name, ingredients, and price of all items offered at the restaurant.

# Instructions
Your response, an enhanced version of every single menu item in the given menu, should strictly be in the format of a valid JSON object.

Generate an enhanced version of every single menu item in the given menu with the following information:
- ** Name **: The name of the menu item you are enriching.
- ** Recommended Upsells **: Enrich our restaurant's menu by creating an Array of Strings for Upselling Recommendations: each string must be only the name of another menu item to upsell and **must not contain any descriptions or sentences**.
- ** Narrative **: Enrich our restaurant's menu by creating a narrative String: an intricate and engaging narrative that connects each menu item with the cultural backgrounds of the three most frequent nationalities among our guests.
- ** Appeal **: Enrich our restaurant's menu by creating an appeal String: Highlight the textures and sensory experience of each menu item, emphasizing what makes them appealing on a tactile and sensory level to encourage customers to try them.
"""
given_menu = txt
user_message_content = f"""
<name> {name} </name>
<location> {location} </location>
<cuisine> {cuisine} </cuisine>
<nationalities> {nationalities} </nationalities>
<menu> {given_menu} </menu>
"""

try:
     validate(instance=given_menu, schema=given_menu_schema)
     print("JSON Schema validated. Input JSON data fits requirements.")
     while True:
          print("Running enhancements...\n")
          completion = client.chat.completions.create(
               model="gpt-4o-2024-08-06",  # model supporting structured outputs
               messages=[{
                    "role": "system", 
                    "content": system_message_content
               },
               {
               "role": "user",
               "content": user_message_content
               }],
               response_format={
                    "type": "json_schema",
                    "json_schema": intermediate_step_schema
               }
          )
          intermediate_step = completion.choices[0].message.content
          intermediate_step_data = json.loads(intermediate_step)  # turn the returned String into a JSON object
          valid = True  # checker variable as we ensure generated content is valid
          file_path = os.path.join('outputs', 'enhanced_menus', 'intermediate_step_output.json')
          os.makedirs(os.path.dirname(file_path), exist_ok=True)  # ensure the file path exists
          try:
               with open(file_path, 'w') as json_file:
                    json.dump(intermediate_step_data, json_file, indent=4)  # write the output to JSON file in the outputs/enhanced_menus folder
                    print(f"Intermediate step generated. Recommended Upsells, Narratives, and Appeals created.\nGenerated content stored in {file_path}.\nEnsuring accuracy of information...\n")
          except FileNotFoundError:
               print(f"The directory for {file_path} does not exist.")
               valid = False
               break

          for menu_item in intermediate_step_data['menu_items']:
               if not dish_exists_in_menu(given_menu, menu_item['name']):  # if generated dish does not exist, regenerate content
                    valid = False
                    print(f"Generated menu item {menu_item['name']} does not exist.")
                    break
               for upsell in menu_item['recommended_upsells']:
                    if not dish_exists_in_menu(given_menu, upsell):  # if generated upsell does not exist, regenerate content
                         valid = False
                         print(f"Recomended upsell {upsell} for generated menu item {menu_item['name']} does not exist.")
                         break
               #print(f'Validating {menu_item['narrative']['nationality']} is in nationalities {nationalities} list...')
               if menu_item['narrative']['nationality'] not in nationalities:
                    valid = False
                    print(f"Mentioned nationality {menu_item['narrative']['nationality']} is not mentioned in guest nationalities.")
                    break
               print(f"\t{menu_item['narrative']['nationality']} confirmed in nationalities list.")
          if valid:
               break
          else:
               print("Generated enhancements are invalid. Trying again...")
    
except ValidationError as e:  # if inputted JSON menu does not follow the schema correctly
     print("Inputted menu JSON data is invalid.")
     print(f"Error message: {e.message}")
     print(f"Invalid data path: {'/'.join(map(str, e.path))}")
     print(f"Schema path: {'/'.join(map(str, e.schema_path))}")

if valid:
     print("\nGenerated enhancements validated. Consolidating enhanced menu...")
# Out:
# JSON Schema validated. Input JSON data fits requirements.
# Running enhancements...
# INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Intermediate step generated. Recommended Upsells, Narratives, and Appeals created.
# Generated content stored in outputs\enhanced_menus\intermediate_step_output.json.
# Ensuring accuracy of information...
#
# 	American confirmed in nationalities list.
# Recomended upsell Grilled green asparagus with romescu and tartar sauce for generated menu item Cecina de bou, esparrecs, formatge Roncal i oli d’amontillat does not exist.
# 	Italian confirmed in nationalities list.
# 	French confirmed in nationalities list.
# 	American confirmed in nationalities list.
# Recomended upsell Red prawn and aioli Fideuà for generated menu item Carpaccio de gamba vermella, fonoll marí i emulsió de ses caps does not exist.
# 	Italian confirmed in nationalities list.
# 	French confirmed in nationalities list.
# 	American confirmed in nationalities list.
# 	Italian confirmed in nationalities list.
# 	French confirmed in nationalities list.
# 	American confirmed in nationalities list.
# Recomended upsell Deep-fried calamari with "Padron" peppers "allioli" for generated menu item Espàrrecs verds a sa brasa amb romesco casolà i salsa tàrtara does not exist.
# 	Italian confirmed in nationalities list.
# 	French confirmed in nationalities list.
# Recomended upsell Zamburiñas with Chardonnay vinegar for generated menu item Ou a baixa temperatura amb salsa de foie i trufa fresca does not exist.
# 	Italian confirmed in nationalities list.
# Mentioned nationality Spanish is not mentioned in guest nationalities.
# Generated enhancements are invalid. Trying again...
# Running enhancements...
# INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Intermediate step generated. Recommended Upsells, Narratives, and Appeals created.
# Generated content stored in outputs\enhanced_menus\intermediate_step_output.json.
# Ensuring accuracy of information...
#
# Recomended upsell Traditional potato salad with shrimps and mayonnaise for generated menu item Pernil ibèric de gla Juan Manuel D.O. Guijuelo (80g) does not exist.
# 	American confirmed in nationalities list.
# Recomended upsell Burrata with roasted eggplant for generated menu item Cecina de bou, esparrecs, formatge Roncal i oli d’amontillat does not exist.
# 	Italian confirmed in nationalities list.
# 	French confirmed in nationalities list.
# 	American confirmed in nationalities list.
# Recomended upsell Zamburiñas with picadillo for generated menu item Ostra a sa brasa amb gamba vermella a l’all does not exist.
# 	Italian confirmed in nationalities list.
# Recomended upsell Burata and roasted eggplant for generated menu item Carpaccio de gamba vermella, fonoll marí i emulsió de ses caps does not exist.
# 	French confirmed in nationalities list.
# 	American confirmed in nationalities list.
# Recomended upsell Txuleta of premium beef for generated menu item Steak tartar de vedella vella de muntanya does not exist.
# 	French confirmed in nationalities list.
# Recomended upsell Low-temperature egg with foie for generated menu item Ensaladilla tradicional de patata amb gamba y mahonesa does not exist.
# Mentioned nationality Spanish is not mentioned in guest nationalities.
# Generated enhancements are invalid. Trying again...
# Running enhancements...
# INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Intermediate step generated. Recommended Upsells, Narratives, and Appeals created.
# Generated content stored in outputs\enhanced_menus\intermediate_step_output.json.
# Ensuring accuracy of information...
#
# 	American confirmed in nationalities list.
# 	Italian confirmed in nationalities list.
# Recomended upsell Arroz del ‘Senyoret’ for generated menu item Ostra Regal Special nº2 al natural does not exist.
# 	French confirmed in nationalities list.
# 	American confirmed in nationalities list.
# Recomended upsell Mix of Calamari, red shrimp, and Croquetas meloses de pernil de Guijuelo for generated menu item Ostra a sa brasa amb gamba vermella a l’all does not exist.
# 	Italian confirmed in nationalities list.
# 	French confirmed in nationalities list.
# 	Italian confirmed in nationalities list.
# 	American confirmed in nationalities list.
# 	Italian confirmed in nationalities list.
# 	French confirmed in nationalities list.
# 	French confirmed in nationalities list.
# Generated enhancements are invalid. Trying again...
# Running enhancements...
# INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Intermediate step generated. Recommended Upsells, Narratives, and Appeals created.
# Generated content stored in outputs\enhanced_menus\intermediate_step_output.json.
# Ensuring accuracy of information...
#
# 	American confirmed in nationalities list.
# 	Italian confirmed in nationalities list.
# 	French confirmed in nationalities list.
# 	American confirmed in nationalities list.
# 	Italian confirmed in nationalities list.
# 	French confirmed in nationalities list.
# 	American confirmed in nationalities list.
# 	Italian confirmed in nationalities list.
# 	French confirmed in nationalities list.
# 	American confirmed in nationalities list.
#
# Generated enhancements validated. Consolidating enhanced menu...
